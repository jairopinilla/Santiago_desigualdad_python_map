# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# incorporamos geopandas! geografía + pandas :)
import geopandas as gpd
from sklearn.preprocessing import normalize

# %matplotlib inline
sns.set(context='notebook', font='Fira Sans', style='white', palette='plasma')

# %%
zonas_eod = gpd.read_file('data/Comunas', encoding="utf-8",converters={'cod_comuna':str})
zonas_eod.head(10)
# Out:
#    objectid     shape_leng  dis_elec  cir_sena  cod_comuna  codregion  \
# 0        48  170038.624165        16         8        6204          6
# 1        29  125730.104795        15         8        6102          6
# 2        30   63026.084422        15         8        6103          6
# 3        31   89840.903562        15         8        6104          6
# 4        78  122626.493264        23        11        9121          9
# 5        79  279935.999530        23        11        9103          9
# 6        81  213151.717476        23        11        9105          9
# 7        82  142385.870502        22        11        9106          9
# 8        34   56156.623059        15         8        6106          6
# 9        37  109700.558035        15         8        6109          6
#
#      st_area_sh     st_length_                                    Region  \
# 0  9.685774e+08  206184.271675  Región del Libertador Bernardo O'Higgins
# ...

# %%
zonas_eod.plot(figsize=(20, 20), color='#efefef', edgecolor='#abacab', linewidth=0.5)
